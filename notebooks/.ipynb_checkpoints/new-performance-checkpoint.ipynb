# %%
import signac
import matplotlib.pyplot as plt
import numpy as np

import gsd.hoomd

# Matplotlib RC Params:    
color_dict = {1.0: "#0F0E0F", 0.8: "#666666", 0.7: "#964d4d", 0.6: "#d03f3f"}
plt.rcParams["figure.figsize"] = (3, 3)
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["legend.fontsize"] = 7
plt.rcParams['lines.markersize'] = 3
plt.rcParams["lines.linestyle"] = "-"
plt.rcParams["lines.marker"] = "o"
plt.rcParams["lines.linewidth"] = 1
plt.rcParams["figure.dpi"] = 1200

# %%
project = signac.get_project(
    "../coarse-grain-sims/performance/flow-templates/flow-templates/flowermd/flowermd-nvt/"
)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 project = signac.get_project(
#       2     "../coarse-grain-sims/performance/flow-templates/flow-templates/flowermd/flowermd-nvt/"
#       3 )
#
# File ~/miniconda3/envs/pekkcg-analysis/lib/python3.11/site-packages/signac/contrib/project.py:3057, in get_project(root, search, **kwargs)
#    3029 def get_project(root=None, search=True, **kwargs):
#    3030     r"""Find a project configuration and return the associated project.
#    3031
#    3032     Parameters
#    (...)
#    3055
#    3056     """
# -> 3057     return Project.get_project(root=root, search=search, **kwargs)
#
# File ~/miniconda3/envs/pekkcg-analysis/lib/python3.11/site-packages/signac/contrib/project.py:2347, in Project.get_project(cls, root, search, **kwargs)
#    2342 config = load_config(root=root, local=False)
#    2343 if "project" not in config or (
#    2344     not search
#    2345     and os.path.realpath(config["project_dir"]) != os.path.realpath(root)
#    2346 ):
# -> 2347     raise LookupError(
#    2348         "Unable to determine project id for path '{}'.".format(
#    2349             os.path.abspath(root)
#    2350         )
#    2351     )
#    2353 return cls(config=config, **kwargs)
#
# LookupError: Unable to determine project id for path '/home/erjank_project/chrisjones/pekk-msibi-final/coarse-grain-sims/performance/flow-templates/flow-templates/flowermd/flowermd-nvt'.

# %%
cg_tps = []
aa_tps = []
ua_tps = []
aa_n_monomers = []
ua_n_monomers = []
cg_n_monomers = []
n_monomers = []

for N, jobs in project.find_jobs().groupby("doc.n_duplicates"):
    if N == 0:
        N = 1
    for job in jobs:
        try:
            if N == 1:
                data = np.genfromtxt(job.fn("seed-log.txt"), names=True)
            else:
                data = np.genfromtxt(job.fn("sim_data.txt"), names=True)
                
            tps = data["flowermdbasesimulationSimulationtps"]
            if job.sp.coarse_grain:
                cg_tps.append(np.mean(tps[-10:]))
            else:
                if not job.sp.remove_hydrogens:
                    aa_tps.append(np.mean(tps[-10:]))
                else:
                    ua_tps.append(np.mean(tps[-10:]))
        except:
            print(job.id)
    n_monomers.append(job.doc.n_monomers)

# %%
#plt.plot(n_monomers, aa_tps, "o-", label="AA")
plt.plot(n_monomers, ua_tps, "o-", label="U.A. Model")
plt.plot(n_monomers, cg_tps, "o-", label="C.G. Model")
plt.xlabel("$N_{monomers}$")
plt.ylabel("TPS")
plt.xscale("log")
plt.legend()
plt.tight_layout()
plt.savefig("figures/tps.png")

# %%
plt.plot(n_monomers, np.array(cg_tps)//np.array(ua_tps), "o-", label="CG / UA")
#plt.plot(n_monomers, np.array(cg_tps)//np.array(aa_tps), "o-", label="CG / AA")
plt.xlabel("N monomers")
plt.ylabel("TPS Ratio")
plt.legend()

# %%
for i, j, k in zip(cg_n_monomers, cg_tps, aa_tps):
    print(i, int(j), int(k), print(j/k)
# Out:
# 400 4285 2017
# 1600 3182 490
# 3200 3114 239
# 6400 2101 121
# 12800 1475 59
# 25600 851 30
# 51200 449 21
